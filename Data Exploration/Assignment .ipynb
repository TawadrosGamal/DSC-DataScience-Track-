# %% [markdown]
# ![WhatsApp%20Image%202020-09-logo%20at%2011.52.29%20PM.jpeg](attachment:WhatsApp%20Image%202020-09-logo%20at%2011.52.29%20PM.jpeg)

# %% [markdown]
# # before exploring you will need to laod in the data first

# %%
# this step is done for you 
import pandas as pd
import numpy as np

# %%
# this is the data
df= pd.read_csv('drug200.csv')

# %% [markdown]
# ## view the data and print couple of columns to see how it's sorted

# %%
# visualize the dataframe

# %% [markdown]
# ## print important info and description about your data

# %%
# look up your data using info

# %%
# look yp your data using descripe

# %% [markdown]
# ## determine which columns to keep and which to use

# %%
# walk through your columns and see

# %% [markdown]
# ## look for missing data

# %%
# using isnan function

# %%
# if there's any then decide to throw the data or to fill it

# %% [markdown]
# ## look for categorical columns and see if they are worth it to use

# %%
# check for categorical columns in your df

# %%
# create dummy variables / one hot encoding from them

# %% [markdown]
# ## split your data to features and labels

# %%
# see which is the label or output intended and put it in y - dependant variable

# %%
# see which from the columns can be used to predict the output and put it in x - independant variable

# %% [markdown]
# # If you successfully done this task then give your self a treat!,
# # Now you can walk through any dataset and explore it all alone.
