# %% [markdown]
# # Scalling

# %% [markdown]
# Mohammed A. El-Agha
# dev.magha@gmail.com
# linkedin.com/in/mohammedagha

# %% [markdown]
# ### Data & Data Preprocessing

# %%
import pandas as pd

# %%
names = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 
         'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
         'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data', names=names, thousands=r',')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
data = data.replace(['?'], pd.NA)

# %%
data
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3              <NA>  alfa-romero  ...       21          27  13495
# 1            3              <NA>  alfa-romero  ...       21          27  16500
# 2            1              <NA>  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
data = data.dropna(axis=0)

# %%
data
# Out:
#      symboling normalized-losses   make  ... city-mpg highway-mpg  price
# 3            2               164   audi  ...       24          30  13950
# 4            2               164   audi  ...       18          22  17450
# 6            1               158   audi  ...       19          25  17710
# 8            1               158   audi  ...       17          20  23875
# 10           2               192    bmw  ...       23          29  16430
# ..         ...               ...    ...  ...      ...         ...    ...
# 200         -1                95  volvo  ...       23          28  16845
# 201         -1                95  volvo  ...       19          25  19045
# 202         -1                95  volvo  ...       18          23  21485
# 203         -1                95  volvo  ...       26          27  22470
# 204         -1                95  volvo  ...       19          25  22625
#
# [159 rows x 26 columns]

# %%
categorial_cols = ['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 
                   'num-of-cylinders', 'fuel-system']

# %%
for col_name in categorial_cols:
    if(data[col_name].dtype == 'object'):
        data[col_name]= data[col_name].astype('category')
        data[col_name] = data[col_name].cat.codes
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data
# Out:
#      symboling normalized-losses  make  ...  city-mpg  highway-mpg  price
# 3            2               164     0  ...        24           30  13950
# 4            2               164     0  ...        18           22  17450
# 6            1               158     0  ...        19           25  17710
# 8            1               158     0  ...        17           20  23875
# 10           2               192     1  ...        23           29  16430
# ..         ...               ...   ...  ...       ...          ...    ...
# 200         -1                95    17  ...        23           28  16845
# 201         -1                95    17  ...        19           25  19045
# 202         -1                95    17  ...        18           23  21485
# 203         -1                95    17  ...        26           27  22470
# 204         -1                95    17  ...        19           25  22625
#
# [159 rows x 26 columns]

# %%
data = data.drop('symboling', axis=1)

# %%
data
# Out:
#     normalized-losses  make  fuel-type  ...  city-mpg  highway-mpg  price
# 3                 164     0          1  ...        24           30  13950
# 4                 164     0          1  ...        18           22  17450
# 6                 158     0          1  ...        19           25  17710
# 8                 158     0          1  ...        17           20  23875
# 10                192     1          1  ...        23           29  16430
# ..                ...   ...        ...  ...       ...          ...    ...
# 200                95    17          1  ...        23           28  16845
# 201                95    17          1  ...        19           25  19045
# 202                95    17          1  ...        18           23  21485
# 203                95    17          0  ...        26           27  22470
# 204                95    17          1  ...        19           25  22625
#
# [159 rows x 25 columns]

# %%
X = data.iloc[:, :-1] # [rows_range , cols_range] [:, :-1]

# %%
X
# Out:
#     normalized-losses  make  fuel-type  ...  peak-rpm  city-mpg  highway-mpg
# 3                 164     0          1  ...      5500        24           30
# 4                 164     0          1  ...      5500        18           22
# 6                 158     0          1  ...      5500        19           25
# 8                 158     0          1  ...      5500        17           20
# 10                192     1          1  ...      5800        23           29
# ..                ...   ...        ...  ...       ...       ...          ...
# 200                95    17          1  ...      5400        23           28
# 201                95    17          1  ...      5300        19           25
# 202                95    17          1  ...      5500        18           23
# 203                95    17          0  ...      4800        26           27
# 204                95    17          1  ...      5400        19           25
#
# [159 rows x 24 columns]

# %%
Y = data.iloc[:, -1]

# %%
Y
# Out:
# 3      13950
# 4      17450
# 6      17710
# 8      23875
# 10     16430
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 159, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minMaxScaler = MinMaxScaler()

# %%
minMaxScaledX = minMaxScaler.fit_transform(X)

# %%
minMaxScaledX
# Out:
# array([[0.51832461, 0.        , 1.        , ..., 0.55102041, 0.26470588,
#         0.33333333],
#        [0.51832461, 0.        , 1.        , ..., 0.55102041, 0.08823529,
#         0.11111111],
#        [0.48691099, 0.        , 1.        , ..., 0.55102041, 0.11764706,
#         0.19444444],
#        ...,
#        [0.15706806, 1.        , 1.        , ..., 0.55102041, 0.08823529,
#         0.13888889],
#        [0.15706806, 1.        , 0.        , ..., 0.26530612, 0.32352941,
#         0.25      ],
#        [0.15706806, 1.        , 1.        , ..., 0.51020408, 0.11764706,
#         0.19444444]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.kdeplot(X)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
minMaxScaledXDF = pd.DataFrame(minMaxScaledX)

# %%
sns.kdeplot(minMaxScaledXDF)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %% [markdown]
# ---

# %% [markdown]
# ### Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
standardScaledX = standardScaler.fit_transform(X)

# %%
standardScaledXDF = pd.DataFrame(standardScaledX)

# %%
sns.kdeplot(standardScaledXDF)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
# 1, 2, 3, 10, 20, 50, 8000

# %% [markdown]
# ---

# %% [markdown]
# ### Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
robustScaler = RobustScaler()
robustScaledX = robustScaler.fit_transform(X)

# %%
robustScaledXDF = pd.DataFrame(robustScaledX)

# %%
sns.kdeplot(robustScaledXDF)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
# age, mark_1, mark_2, family, married, -> gpa

robustScaler.fit_transform(data[['age', 'family', 'married']])
