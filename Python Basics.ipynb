# %% [markdown]
# ![footerLogo.png](data:image/png;base64,...)

# %% [markdown]
# #PYTHON IN A NUTSHELL
#
# ---

# %%
print("Hello world")
print(5)
# Out:
# Hello world
# 5

# %% [markdown]
# ##Data types
# Int like 3
#
# ---
#
#
# float like 3.3
#
# ---
#
#
# string like "PYthon"
#
# ---
#
#
# Nonedatatype is None
#
# ---
#
#
# x = None

# %%
x = 123
print(type(x))
# Out:
# <class 'int'>

# %%
x = 3.2
print(type(x))
# Out:
# <class 'float'>

# %%
s = "123"             # s = 123
print(type(s))
# Out:
# <class 'str'>

# %%
z = int(s)
print(z)
print(type(z))
# Out:
# 123
# <class 'int'>

# %%
q = int(2.2)
print (q)
x= float(2)
print(x)
# Out:
# 2
# 2.0

# %% [markdown]
# ##Math Operations

# %%
m = 5 + 10

m1 = 5 * 10

m2 = 5 - 10

m3 = 10 / 3

m4 = int(m3)

m5 = 10//3

print (m)
print (m1)
print (m2)
print (m3)
print (m4)
print (m5)
# Out:
# 15
# 50
# -5
# 3.3333333333333335
# 3
# 3

# %%
n = 10 % 3

n1 = 3 % 10
 
n2 = 3 % 3
print(n)
print(n1)
print(n2)
# Out:
# 1
# 3
# 0

# %%
k= 2**3
print(k)
# Out:
# 8

# %% [markdown]
# ##Logic Gates : and , or , not

# %%
print(True and False)
print(True or False)
print(not True )
print(not False )
# Out:
# False
# True
# False
# True

# %%
print((False == 0) and (True == 1))
# Out:
# True

# %%
name = "Ahmad"
print (name)
introName= "I am "+ name 
print(introName)
# Out:
# Ahmad
# I am Ahmad

# %%
print(name[1:3]) 
print(name[4])
print(name[:4])
# Out:
# hm
# d
# Ahma

# %%
print(name[7])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-af172c4a2a80> in <module>
# ----> 1 print(name[7])
#
# NameError: name 'name' is not defined

# %%
 Name = "Developer Student Club "
print(len(Name))
# Out:
# 23

# %%
Name1 = Name.replace("Student", "")
print(Name1)
# Out:
# Developer  Club

# %% [markdown]
# ##IF condition:

# %%
p = 3
if(p == 1):
    print("one")
elif(p == 2):
    print("two")
else:
    print("other")
# Out:
# other

# %% [markdown]
# ##For Loop

# %%
for i in range(5):
    
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ##While loop

# %%
p=0
while p<5:
    print (p)
    p+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ##Functions

# %%
def hello():
  print("hello all")
hello()
# Out:
# hello all
